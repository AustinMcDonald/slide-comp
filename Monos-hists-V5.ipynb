# %%
import numpy as np
import glob

# for plotting
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
#from matplotlib.colors import LogNorm
# %matplotlib inline


from scipy import interpolate

# %%
ybaE  = np.load("hist-Exp-wba.npy")
nbaE  = np.load("hist-Exp-woba.npy")
glaE  = np.load("hist-Exp-glass.npy")
polE  = np.load("hist-Exp-poly.npy")

# %%
ybaD  = np.load("hist-Des-wba.npy")
nbaD  = np.load("hist-Des-woba.npy")
glaD  = np.load("hist-Des-glass.npy")
polD  = np.load("hist-Des-poly.npy")

# %%
bincenters = np.arange(len(ybaE))

# %%
plt.figure(figsize=(8,8))

plt.plot(bincenters,ybaE ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaE ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polE ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaE ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaD ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaD ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polD ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaD ,color='g',lw=3,linestyle='--')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
ybaE6  = np.load("hist-Exp6-wba.npy")
nbaE6  = np.load("hist-Exp6-woba.npy")
glaE6  = np.load("hist-Exp6-glass.npy")
polE6  = np.load("hist-Exp6-poly.npy")

# %%
ybaD6  = np.load("hist-Des6-wba.npy")
nbaD6  = np.load("hist-Des6-woba.npy")
glaD6  = np.load("hist-Des6-glass.npy")
polD6  = np.load("hist-Des6-poly.npy")

# %%
plt.figure(figsize=(8,8))

plt.plot(bincenters,ybaE6 ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaE6 ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polE6 ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaE6 ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaD6 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaD6 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polD6 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaD6 ,color='g',lw=3,linestyle='--')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
ybaE12  = np.load("hist-Exp12-wba.npy")
nbaE12  = np.load("hist-Exp12-woba.npy")
glaE12  = np.load("hist-Exp12-glass.npy")
polE12  = np.load("hist-Exp12-poly.npy")

ybaD12  = np.load("hist-Des12-wba.npy")
nbaD12  = np.load("hist-Des12-woba.npy")
glaD12  = np.load("hist-Des12-glass.npy")
polD12  = np.load("hist-Des12-poly.npy")

# %%
plt.figure(figsize=(8,8))

plt.plot(bincenters,ybaE12 ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaE12 ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polE12 ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaE12 ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaD12 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaD12 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polD12 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaD12 ,color='g',lw=3,linestyle='--')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
ybaE20  = np.load("hist-Exp20-wba.npy")
nbaE20  = np.load("hist-Exp20-woba.npy")
glaE20  = np.load("hist-Exp20-glass.npy")
polE20  = np.load("hist-Exp20-poly.npy")

ybaD20  = np.load("hist-Des20-wba.npy")
nbaD20  = np.load("hist-Des20-woba.npy")
glaD20  = np.load("hist-Des20-glass.npy")
polD20  = np.load("hist-Des20-poly.npy")

# %%
plt.figure(figsize=(8,8))

plt.plot(bincenters,ybaE20 ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaE20 ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polE20 ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaE20 ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaD20 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaD20 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polD20 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaD20 ,color='g',lw=3,linestyle='--')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title("Exposed run comparasion", fontsize=18)
plt.plot(bincenters,ybaE ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaE ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polE ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaE ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaE6 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaE6 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polE6 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaE6 ,color='g',lw=3,linestyle='--')

plt.plot(bincenters,ybaE12 ,color='k',lw=3,linestyle=':')
plt.plot(bincenters,nbaE12 ,color='r',lw=3,linestyle=':')
plt.plot(bincenters,polE12 ,color='b',lw=3,linestyle=':')
plt.plot(bincenters,glaE12 ,color='g',lw=3,linestyle=':')

plt.plot(bincenters,ybaE20 ,color='k',lw=3,linestyle='-.')
plt.plot(bincenters,nbaE20 ,color='r',lw=3,linestyle='-.')
plt.plot(bincenters,polE20 ,color='b',lw=3,linestyle='-.')
plt.plot(bincenters,glaE20 ,color='g',lw=3,linestyle='-.')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title("Desiccated run comparasion", fontsize=18)
plt.plot(bincenters,ybaD ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters,nbaD ,color='r',label="Barium free",lw=3)
plt.plot(bincenters,polD ,color='b',label="poly",lw=3)
plt.plot(bincenters,glaD ,color='g',label="glass",lw=3)


plt.plot(bincenters,ybaD6 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters,nbaD6 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters,polD6 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters,glaD6 ,color='g',lw=3,linestyle='--')


plt.plot(bincenters,ybaD12 ,color='k',lw=3,linestyle=':')
plt.plot(bincenters,nbaD12 ,color='r',lw=3,linestyle=':')
plt.plot(bincenters,polD12 ,color='b',lw=3,linestyle=':')
plt.plot(bincenters,glaD12 ,color='g',lw=3,linestyle=':')

plt.plot(bincenters,ybaD20 ,color='k',lw=3,linestyle='-.')
plt.plot(bincenters,nbaD20 ,color='r',lw=3,linestyle='-.')
plt.plot(bincenters,polD20 ,color='b',lw=3,linestyle='-.')
plt.plot(bincenters,glaD20 ,color='g',lw=3,linestyle='-.')

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
def find_nearest(a, a0):
    "Element in nd array `a` closest to the scalar value `a0`"
    idx = np.abs(a - a0).argmin()
    return a.flat[idx]

# %%
fnd = find_nearest(glaE, 1000)
np.where(glaE == fnd)[0][0]
# Out:
# 66

# %%
glaE[66]
# Out:
# 1032

# %%
fnd = find_nearest(glaE, 1000)
fct = 60/(np.where(glaE == fnd)[0][0])

# %%
bincenters[66]*fct
# Out:
# 60.0

# %%
## shiffting for the glass systematic
plt.figure(figsize=(8,8))
plt.title("Exposed run comparasion corrected", fontsize=18)

fnd = find_nearest(glaE, 1000)
fct = 60/(np.where(glaE == fnd)[0][0])
plt.plot(bincenters*fct,ybaE ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters*fct,nbaE ,color='r',label="Barium free",lw=3)
plt.plot(bincenters*fct,polE ,color='b',label="poly",lw=3)
#f1 = interpolate.interp1d(bincenters, glaE)
plt.plot(bincenters*fct,glaE ,color='g',label="glass",lw=3)

fnd = find_nearest(glaE6, 1000)
fct = 60/(np.where(glaE6 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE6 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters*fct,nbaE6 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters*fct,polE6 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters*fct,glaE6 ,color='g',lw=3,linestyle='--')

fnd = find_nearest(glaE12, 1000)
fct = 60/(np.where(glaE12 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE12 ,color='k',lw=3,linestyle=':')
plt.plot(bincenters*fct,nbaE12 ,color='r',lw=3,linestyle=':')
plt.plot(bincenters*fct,polE12 ,color='b',lw=3,linestyle=':')
plt.plot(bincenters*fct,glaE12 ,color='g',lw=3,linestyle=':')

fnd = find_nearest(glaE20, 1000)
fct = 60/(np.where(glaE20 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE20 ,color='k',lw=3,linestyle='-.')
plt.plot(bincenters*fct,nbaE20 ,color='r',lw=3,linestyle='-.')
plt.plot(bincenters*fct,polE20 ,color='b',lw=3,linestyle='-.')
plt.plot(bincenters*fct,glaE20 ,color='g',lw=3,linestyle='-.')


plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
## shiffting for the glass systematic
plt.figure(figsize=(7,7))

fnd = find_nearest(glaE20, 1000)
fct = 60/(np.where(glaE20 == fnd)[0][0])
XX  = bincenters*fct
plt.plot(XX,ybaE20*XX ,color='k',label="Barium spiked",lw=3)
plt.plot(XX,nbaE20*XX ,color='r',label="Barium free",lw=3)
plt.plot(XX,polE20*XX ,color='b',label="poly",lw=3)
plt.plot(XX,glaE20*XX ,color='g',label="glass",lw=3)

plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Image intensity',fontsize = 22)
plt.ylabel('Intensity per Bin',fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('BaComp-one.png',dpi=400)
plt.show()

# %%
## shiffting for the glass systematic
plt.figure(figsize=(7,7))

fnd = find_nearest(glaE, 1000)
fct = 60/(np.where(glaE == fnd)[0][0])
XX  = bincenters*fct
plt.plot(bincenters*fct,ybaE*XX ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters*fct,nbaE*XX ,color='r',label="Barium free",lw=3)
plt.plot(bincenters*fct,polE*XX ,color='b',label="poly",lw=3)
plt.plot(bincenters*fct,glaE*XX ,color='g',label="glass",lw=3)

fnd = find_nearest(glaE6, 1000)
fct = 60/(np.where(glaE6 == fnd)[0][0])
XX  = bincenters*fct
plt.plot(bincenters*fct,ybaE6*XX ,color='k',lw=3,linestyle='--')
plt.plot(bincenters*fct,nbaE6*XX ,color='r',lw=3,linestyle='--')
plt.plot(bincenters*fct,polE6*XX ,color='b',lw=3,linestyle='--')
plt.plot(bincenters*fct,glaE6*XX ,color='g',lw=3,linestyle='--')

fnd = find_nearest(glaE12, 1000)
fct = 60/(np.where(glaE12 == fnd)[0][0])
XX  = bincenters*fct
plt.plot(bincenters*fct,ybaE12*XX ,color='k',lw=3,linestyle=':')
plt.plot(bincenters*fct,nbaE12*XX ,color='r',lw=3,linestyle=':')
plt.plot(bincenters*fct,polE12*XX ,color='b',lw=3,linestyle=':')
plt.plot(bincenters*fct,glaE12*XX ,color='g',lw=3,linestyle=':')

fnd = find_nearest(glaE20, 1000)
fct = 60/(np.where(glaE20 == fnd)[0][0])
XX  = bincenters*fct
plt.plot(bincenters*fct,ybaE20*XX ,color='k',lw=3,linestyle='-.')
plt.plot(bincenters*fct,nbaE20*XX ,color='r',lw=3,linestyle='-.')
plt.plot(bincenters*fct,polE20*XX ,color='b',lw=3,linestyle='-.')
plt.plot(bincenters*fct,glaE20*XX ,color='g',lw=3,linestyle='-.')


plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Image intensity',fontsize = 22)
plt.ylabel('Intensity per Bin',fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('BaComp-ALL.png',dpi=400)
plt.show()

# %%
## shiffting for the glass systematic
plt.figure(figsize=(7,7))

fnd   = find_nearest(glaE, 1000)
fct   = 60/(np.where(glaE == fnd)[0][0])
fnd   = find_nearest(glaE6, 1000)
fct6  = 60/(np.where(glaE6 == fnd)[0][0])
fnd   = find_nearest(glaE12, 1000)
fct12 = 60/(np.where(glaE12 == fnd)[0][0])
fnd   = find_nearest(glaE20, 1000)
fct20 = 60/(np.where(glaE20 == fnd)[0][0])

BS = np.array([ybaE*bincenters*fct, ybaE6*bincenters*fct6, ybaE12*bincenters*fct12, ybaE20*bincenters*fct20])
EBp = np.max(BS,axis=0)
EBm = np.min(BS,axis=0)
plt.plot(bincenters, np.mean(BS,axis=0), color='k',label="Barium spiked",lw=3)
plt.fill_between(bincenters, EBm,EBp,color='k',alpha=0.3)


BS = np.array([nbaE*bincenters*fct, nbaE6*bincenters*fct6, nbaE12*bincenters*fct12, nbaE20*bincenters*fct20])
EBp = np.max(BS,axis=0)
EBm = np.min(BS,axis=0)
plt.plot(bincenters, np.mean(BS,axis=0), color='r',label="Barium free",lw=3)
plt.fill_between(bincenters, EBm,EBp,color='r',alpha=0.3)



BS = np.array([polE*bincenters*fct, polE6*bincenters*fct6, polE12*bincenters*fct12, polE20*bincenters*fct20])
EBp = np.max(BS,axis=0)
EBm = np.min(BS,axis=0)
plt.plot(bincenters, np.mean(BS,axis=0), color='b',label="Poly",lw=3)
plt.fill_between(bincenters, EBm,EBp,color='b',alpha=0.3)

BS = np.array([glaE*bincenters*fct, glaE6*bincenters*fct6, glaE12*bincenters*fct12, glaE20*bincenters*fct20])
EBp = np.max(BS,axis=0)
EBm = np.min(BS,axis=0)
plt.plot(bincenters, np.mean(BS,axis=0), color='g',label="Glass",lw=3)
plt.fill_between(bincenters, EBm,EBp,color='g',alpha=0.3)


plt.legend(loc='upper right',fontsize=17)
plt.xlabel('Image intensity',fontsize = 22)
plt.ylabel('Intensity per Bin',fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,165)
plt.ylim(101,3e7)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('BaComp-ALL-NiceNice.png',dpi=400)
plt.show()

# %%
## shiffting for the glass systematic
plt.figure(figsize=(8,8))
plt.title("Exposed run comparasion corrected", fontsize=18)

fnd = find_nearest(glaE, 1000)
fct = 60/(np.where(glaE == fnd)[0][0])
plt.plot(bincenters*fct,ybaE ,color='k',label="Barium spiked",lw=3)
plt.plot(bincenters*fct,nbaE ,color='r',label="Barium free",lw=3)
plt.plot(bincenters*fct,polE ,color='b',label="poly",lw=3)
#f1 = interpolate.interp1d(bincenters, glaE)
plt.plot(bincenters*fct,glaE ,color='g',label="glass",lw=3)

fnd = find_nearest(glaE6, 1000)
fct = 60/(np.where(glaE6 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE6 ,color='k',lw=3,linestyle='--')
plt.plot(bincenters*fct,nbaE6 ,color='r',lw=3,linestyle='--')
plt.plot(bincenters*fct,polE6 ,color='b',lw=3,linestyle='--')
plt.plot(bincenters*fct,glaE6 ,color='g',lw=3,linestyle='--')

fnd = find_nearest(glaE12, 1000)
fct = 60/(np.where(glaE12 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE12 ,color='k',lw=3,linestyle=':')
plt.plot(bincenters*fct,nbaE12 ,color='r',lw=3,linestyle=':')
plt.plot(bincenters*fct,polE12 ,color='b',lw=3,linestyle=':')
plt.plot(bincenters*fct,glaE12 ,color='g',lw=3,linestyle=':')

fnd = find_nearest(glaE20, 1000)
fct = 60/(np.where(glaE20 == fnd)[0][0])
plt.plot(bincenters*fct,ybaE20 ,color='k',lw=3,linestyle='-.')
plt.plot(bincenters*fct,nbaE20 ,color='r',lw=3,linestyle='-.')
plt.plot(bincenters*fct,polE20 ,color='b',lw=3,linestyle='-.')
plt.plot(bincenters*fct,glaE20 ,color='g',lw=3,linestyle='-.')


plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
xnew = np.arange(0,200,0.1)

# %%
## shiffting for the glass systematic
plt.figure(figsize=(8,8))
plt.title("Exposed run comparasion corrected", fontsize=18)
#f1 = interpolate.interp1d(bincenters, glaE)

fnd = find_nearest(glaE, 1000)
fct = 60/(np.where(glaE == fnd)[0][0])
f1 = interpolate.interp1d(bincenters*fct, ybaE)
plt.plot(bincenters*fct,ybaE ,color='k',label="Barium spiked",lw=3)


fnd = find_nearest(glaE6, 1000)
fct = 60/(np.where(glaE6 == fnd)[0][0])
f2 = interpolate.interp1d(bincenters*fct, ybaE6)
plt.plot(bincenters*fct,ybaE6 ,color='k',lw=3,linestyle='--')

fnd = find_nearest(glaE12, 1000)
fct = 60/(np.where(glaE12 == fnd)[0][0])
f3 = interpolate.interp1d(bincenters*fct, ybaE12)
plt.plot(bincenters*fct,ybaE12 ,color='k',lw=3,linestyle=':')

plt.plot(xnew,f1(xnew) ,color='r',lw=1)
plt.plot(xnew,f2(xnew) ,color='r',lw=1)
plt.plot(xnew,f3(xnew) ,color='r',lw=1)
s = np.array([f1(xnew),f2(xnew),f3(xnew)])
ss = np.mean(s,axis=0)
sss=np.std(s,axis=0)
plt.plot(xnew,ss ,color='g')
plt.plot(xnew,ss+sss ,color='m')
plt.plot(xnew,ss-sss ,color='m')


plt.legend(loc='upper right',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,160)
plt.ylim(1,2e6)

plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()

# %%
sss[800]
# Out:
# 4282.509071866314

# %%
xnew[800]
# Out:
# 80.0

# %%
con = 1.1
xnew = np.arange(0, 200, 0.1)
plt.figure(figsize=(8,8))

one = Baspik06/np.sum(Baspik06)
#one[one<1e-8] = 1e-8
two = Baspik05/np.sum(Baspik05)
#two[two<1e-8] = 1e-8
f1 = interpolate.interp1d(bincenters, one)
f2 = interpolate.interp1d(bincenters*con, two)
this = (f2(xnew) - f1(xnew))/f1(xnew)
plt.plot(xnew,this ,color='k',label="Barium spiked 06-05 ",lw=3)

one = Bafree06/np.sum(Bafree06)
two = Bafree05/np.sum(Bafree05)
f1 = interpolate.interp1d(bincenters, one)
f2 = interpolate.interp1d(bincenters*con, two)
this = (f2(xnew) - f1(xnew))/f1(xnew)
plt.plot(xnew,this ,color='r',label="Barium free 06-05 ",lw=3)

one = Poly06/np.sum(Poly06)
two = Poly05/np.sum(Poly05)
f1 = interpolate.interp1d(bincenters, one)
f2 = interpolate.interp1d(bincenters*con, two)
this = (f2(xnew) - f1(xnew))/f1(xnew)
plt.plot(xnew,this ,color='b',label="Poly 06-05 ",lw=3)

one = Glass06/np.sum(Glass06)
two = Glass05/np.sum(Glass05)
f1 = interpolate.interp1d(bincenters, one)
f2 = interpolate.interp1d(bincenters*con, two)
this = (f2(xnew) - f1(xnew))/f1(xnew)
plt.plot(xnew,this ,color='g',label="glass06-05 ",lw=3)


plt.legend(loc='upper left',fontsize=16)
plt.xlabel('Pixel intensity',fontsize = 18)
plt.ylabel('Counts',fontsize = 18)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlim(0,140)
plt.ylim(-2,12)
#plt.semilogy()
plt.grid(True)
plt.tight_layout()

#plt.savefig('bar10.png',dpi=400)
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in true_divide
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in true_divide
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in true_divide
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: divide by zero encountered in true_divide
# ...
